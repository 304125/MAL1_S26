# %% [markdown]
# # Exercises on performace metrics and validation methods
#
# Note: you might not need all these libraries in your approach. Use those that are relevant for you.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %% [markdown]
# ## 1. Create dataset

# %%
X, y = make_classification(n_samples=1000, n_features=10, n_informative=5,
                           n_redundant=2, weights=[0.8, 0.2], random_state=42)

# %%
# visualization of the dataset
plt.figure(figsize=(10, 6))
sns.scatterplot(x=X[:, 0], y=X[:, 1], hue=y, palette="Set1")
plt.title("Visualization of the dataset")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.legend(title="Class")
plt.show()

# %% [markdown]
# ## 2. Split the dataset into training and testing sets
#
# a) Split the dataset into training, validation and testing sets using two 80-20 splits.
#
# b) Look at the distribution of each set and make sure that the target variable is distributed similarly across the sets.

# %% [markdown]
# ## 3. Classification models
#
# a) Train a kNN classifier, finding the best value of k using the validation set.
#
# b) Train a decision tree classifier, finding the best value of max_depth using the validation set.
#
# c) Train a random forest classifier, finding the best values of n_estimators and max_depth using the validation set.

# %% [markdown]
# ## 4. Evaluation
#
# a) Visualize the confusion matrix for each of the three models on the validation set.
#
# b) Evaluate the performance of the three models on the validation set using accuracy, precision, recall and F1 score.
#
# c) Consider that the data is showing cancer diagnosis, where the positive class (1) represents a cancer diagnosis and the negative class (0) represents no cancer. In this case, which metric would you prioritize and why?

# %% [markdown]
# ## 5. Test set evaluation
#
# a) Evaluate the best performing model on the test set using the same metrics as in the validation set.
#
# b) Compare the performance of the best model on the validation set and the test set. Is there a significant drop in performance? What could be the reasons for this?
